# %% [markdown]
# ## Домашнее задание
# Для выполнения задач Easy и Normal опять используем данные Титаника
#
# ### Easy
# Вычислить вероятность выживания, если пассажиру:
#
# от 0 до 25 лет
#
# от 25 до 50 лет
#
# от 50 лет и старше
#
# ### Normal
# Вычислить с какой вероятностью пассажир женского пола, если известно, что он выжил (использовать теорему Байеса)
#
# ### Normal+
# Необходимо реализовать градиентный спуск с уменьшением  𝜖  для функции двух переменных.
#
# Проверить на функции  𝑓(𝑥,𝑦)=(𝑥−3)4+(𝑦+5)2 . Начать из точки (5, 2).
#
# Проверить свое решение на готовых функциях минимизации.
#
# ### Hard
# Закон распределения задается функцией плотности
#
# 𝑓(𝑥)=𝜆𝑒−𝜆𝑥,𝑥>0
# 𝑓(𝑥)=0,𝑥<=0
# Найти вероятность того, что событие произойдет при  𝑥∈[1,2]
# P.S. в scipy есть функция для интегрирования функции

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/train.csv', index_col=0)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # Easy

# %%
#Выжившие от от 0 до 25 лет
young_survived = df[(df['Survived'] == 1) & (df['Age'] < 25)].shape[0]
#print(young_survived)

#Выжившие от 25 до 50 лет
med_survived = df[(df['Survived'] == 1) & ((df['Age'] >= 25) & (df['Age'] < 50))].shape[0]
#print(med_survived)

#Выжившие от 50 лет и старше
old_survived = df[(df['Survived'] == 1) & (df['Age'] >= 50)].shape[0]
#print(old_survived)

print(f"""
Вероятность выжить людей в возрасте от 0 до 25 лет {round(young_survived/891*100,2)}% \n
Вероятность выжить людей в возрасте от 25 до 50 лет {round(med_survived/891*100,2)}% \n
Вероятность выжить людей в возрасте от 50 лет {round(old_survived/891*100,2)}% \n
""")
# Out:
# Вероятность выжить людей в возрасте от 0 до 25 лет 13.24%
#
# Вероятность выжить людей в возрасте от 25 до 50 лет 16.27%
#
# Вероятность выжить людей в возрасте от 50 лет 3.03%

# %% [markdown]
# # Normal
